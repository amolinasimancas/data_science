# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("adilshamim8/global-traffic-accidents-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 292k/292k [00:00<00:00, 51.3MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/adilshamim8/global-traffic-accidents-dataset/versions/1

# %%
import pandas as pd

df = pd.read_csv(path + "/global_traffic_accidents.csv")
df.head()
# Out:
#   Accident ID        Date   Time           Location   Latitude   Longitude  \
# 0    b0dd6f57  2023-04-19  06:39      Mumbai, India  13.488432  -73.290682
# 1    debfad09  2023-01-17  02:47  São Paulo, Brazil -37.798317  -32.244242
# 2    6d69aa36  2024-04-09  02:55  Sydney, Australia  33.767869  104.869018
# 3    425bb1f0  2023-10-10  11:23       Tokyo, Japan  -0.378031 -165.825855
# 4    90d5cf62  2023-01-02  12:07     Beijing, China  41.254879  -30.776959
#
#   Weather Condition Road Condition  Vehicles Involved  Casualties  \
# 0              Snow          Snowy                  5           7
# 1             Clear            Icy                  4           1
# 2              Rain          Snowy                  1           7
# 3             Storm            Wet                  4           0
# 4             Storm          Snowy                  3           9
#
#               Cause
# 0  Reckless Driving
# 1     Drunk Driving
# 2  Reckless Driving
# 3     Drunk Driving
# ...
